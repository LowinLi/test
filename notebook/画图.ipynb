# %%
import matplotlib.pyplot as plt
import pandas as pd
import json
from datetime import datetime, timedelta
items = ['全部', '快乐', '乐观', '平静', '无助', '恐惧', '悲伤', '愤怒', '恐慌', '压力', '抑郁',
       '焦虑']

# %%
def group_week(df):
    df['datetime']=pd.to_datetime(df.index)
    df['week'] = df['datetime'].apply(lambda x: x-timedelta(days = x.weekday()))
    datas = []
    for day, day_df in df.groupby('week'):
        data = [day]
        for item in items:
            data.append(day_df[item].sum())
        datas.append(data)
    new_df = pd.DataFrame(datas,columns=['week']+items).iloc[1:-1]
    new_df.index = pd.to_datetime(new_df['week'])
    return new_df

# %%
with open('/home/lowinli/Desktop/datas.json','r') as file:
    d = json.load(file)
df = pd.DataFrame(d)
df_2 = group_week(df)

# %%
with open('/home/lowinli/Desktop/datas_pro湖北.json','r') as file:
    d = json.load(file)
df_hb = pd.DataFrame(d['湖北'])
df_hb_2 = group_week(df_hb)
with open('/home/lowinli/Desktop/datas_pro河北.json','r') as file:
    d = json.load(file)
df_heb = pd.DataFrame(d['河北'])
df_heb_2 = group_week(df_heb)
with open('/home/lowinli/Desktop/datas_pro河南.json','r') as file:
    d = json.load(file)
df_hn = pd.DataFrame(d['河南'])
df_hn_2 = group_week(df_hn)
with open('/home/lowinli/Desktop/datas_pro福建.json','r') as file:
    d = json.load(file)
df_fj = pd.DataFrame(d['福建'])
df_fj_2 = group_week(df_fj)
with open('/home/lowinli/Desktop/datas_pro上海.json','r') as file:
    d = json.load(file)
df_sh = pd.DataFrame(d['上海'])
df_sh_2 = group_week(df_sh)
with open('/home/lowinli/Desktop/datas_pro四川.json','r') as file:
    d = json.load(file)
df_sc = pd.DataFrame(d['四川'])
df_sc_2 = group_week(df_sc)

# %%
plt.plot(df['全部'],label='quanguo')
plt.plot(df2['全部'],label='wuhan')
plt.legend()
plt.show()

for column in items[1:]:
    print(column)
    plt.plot(df[column]/df['全部'],label='quanguo')
    plt.plot(df2[column]/df2['全部'],label='wuhan')
    plt.legend()
    plt.show()
# Out:
# 快乐
# 乐观
# 平静
# 无助
# 恐惧
# 悲伤
# 愤怒
# 恐慌
# 压力
# 抑郁
# 焦虑

# %%
plt.plot(df_2['全部'],label='quanguo')
plt.plot(df_hb_2['全部'],label='hubei')
plt.plot(df_heb_2['全部'],label='hebei')
plt.plot(df_hn_2['全部'],label='henan')
plt.plot(df_fj_2['全部'],label='fujian')
plt.plot(df_sh_2['全部'],label='shanghai')
plt.plot(df_sc_2['全部'],label='sichuan')
plt.legend()
plt.show()


for column in items[1:]:
    print(column)
    plt.plot(df_2[column]/df_2['全部'],label='quanguo')
    plt.plot(df_hb_2[column]/df_hb_2['全部'],label='hubei')
    plt.plot(df_heb_2[column]/df_heb_2['全部'],label='hebei')
    plt.plot(df_hn_2[column]/df_hn_2['全部'],label='henan')
    plt.plot(df_fj_2[column]/df_fj_2['全部'],label='fujian')
    plt.plot(df_sh_2[column]/df_sh_2['全部'],label='shanghai')
    plt.plot(df_sc_2[column]/df_sc_2['全部'],label='sichuan')
    plt.legend()
    plt.show()
# Out:
# 快乐
# 乐观
# 平静
# 无助
# 恐惧
# 悲伤
# 愤怒
# 恐慌
# 压力
# 抑郁
# 焦虑

# %%
plt.plot(df_2['全部'],label='quanguo')
plt.plot(df_hb_2['全部'],label='hubei')
plt.legend()
plt.show()


for column in items[1:]:
    print(column)
    plt.plot(df_2[column]/df_2['全部'],label='quanguo')
    plt.plot(df_hb_2[column]/df_hb_2['全部'],label='hubei')
    plt.legend()
    plt.show()
# Out:
# 快乐
# 乐观
# 平静
# 无助
# 恐惧
# 悲伤
# 愤怒
# 恐慌
# 压力
# 抑郁
# 焦虑
